# %%
#JSON Based assignment
record = { 11602259 : {"name": "Ashish Jangra" , "Pno": 1234, "cgpa" : 7.5},
           11602260 : {"name": "Gurpreet Singh", "Pno": 5678, "cgpa" : 8},
           11602261 : {"name": "Rishu Kumar"   , "Pno": 8984, "cgpa" : 7.8}
           11602262 : {"name": "Prabhat Meena" , "Pno": 1000, "cgpa" : 7.51},
           11602263 : {"name": "Parafull Singh", "Pno": 1001, "cgpa" : 8.1},
           11602264 : {"name": "Rishi Kumar"   , "Pno": 1002, "cgpa" : 7.82}
           11602265 : {"name": "Ashish Dubey" , "Pno": 1003, "cgpa" : 7.54},
           11602266 : {"name": "Manpreet Singh", "Pno": 1004, "cgpa" : 8.2},
           11602267 : {"name": "Rinku Kumar"   , "Pno": 1005, "cgpa" : 7.85}
           11602268 : {"name": "Prateek Acharya" , "Pno": 1006, "cgpa" : 7.54},
           11602269 : {"name": "Manjeet Singh", "Pno": 1007, "cgpa" : 8},
           11602270 : {"name": "Rishu Kumar"   , "Pno": 1008, "cgpa" : 7.8}
           11602271:  {"name": "Ashi Singh" , "Pno": 1009, "cgpa" : 7.5},
           11602272 : {"name": "Anisha Singh", "Pno": 1010, "cgpa" : 8.6},
           11602273 : {"name": "Rishu Kumar"   , "Pno": 1011, "cgpa" : 7.3}
           11602274 : {"name": "Anu Singh" , "Pno": 1012, "cgpa" : 7.2},
           11602275 : {"name": "Gurpreeti Kaur", "Pno": 1013, "cgpa" : 8.1},
           11602276 : {"name": "Rishu Kumari"   , "Pno": 1014, "cgpa" : 7.88}
           11602277 : {"name": "Debashish Gorai" , "Pno": 1015, "cgpa" : 7.51},
           11602278 : {"name": "Shreya Singh", "Pno": 1016, "cgpa" : 8.09},
           11602279 : {"name": "Rahul Raj"   , "Pno": 1017, "cgpa" : 7.83}
           11602280 : {"name": "Priya singh" , "Pno": 1018, "cgpa" : 7.55},
           11602281 : {"name": "Ashotosh Singh", "Pno": 1019, "cgpa" : 8.78},
           11602282 : {"name": "Santosh Kumar"   , "Pno": 1020, "cgpa" : 7.8}
           11602283 : {"name": "Ashish Yadav" , "Pno": 1021, "cgpa" : 7.59},
           11602284 : {"name": "Preeti Singh", "Pno": 1022, "cgpa" : 8.33},
           11602285 : {"name": "Ishu Kumar"   , "Pno": 1023, "cgpa" : 7.88}
           11602286 : {"name": "AshisH Singh" , "Pno": 1024, "cgpa" : 7.05},
           11602287 : {"name": "Preet Singh", "Pno": 1025, "cgpa" : 8.3},
           11602288 : {"name": "Pritam Kumar"   , "Pno": 1026, "cgpa" : 7.82}
           11602289 : {"name": "Sankar Gupta" , "Pno": 1027, "cgpa" : 7.59}}
           
In [59]:
reg = 11602260

print(record[reg]['name'])
print(record[reg]['Pno'])
print(record[reg]['cgpa'])
Gurpreet Singh
5678
8.2
In [62]:
record[11602260]['Pno'] = 999
In [65]:
record
Out[65]:
{11602259: {'Pno': 5678, 'cgpa': 8.2, 'name': 'Gurpreet Singh'},
 11602261: {'Pno': 8984, 'cgpa': 7.8, 'name': 'Rishu Kumar'}}
In [ ]:
record = { 11602259 : {"name": "Ashish Jangra" , "Pno": 1234, "cgpa" : 7.5},
           11602260 : {"name": "Gurpreet Singh", "Pno": 5678, "cgpa" : 8.2},
           11602261 : {"name": "Rishu Kumar"   , "Pno": 8984, "cgpa" : 7.8}}
In [67]:
import json
In [68]:
js = json.dumps(record)
In [69]:
js
Out[69]:
'{"11602259": {"name": "Gurpreet Singh", "Pno": 5678, "cgpa": 8.2}, "11602261": {"name": "Rishu Kumar", "Pno": 8984, "cgpa": 7.8}}'
In [73]:
record
Out[73]:
{11602259: {'Pno': 5678, 'cgpa': 8.2, 'name': 'Gurpreet Singh'},
 11602261: {'Pno': 8984, 'cgpa': 7.8, 'name': 'Rishu Kumar'}}
In [71]:
type(js)
Out[71]:
str
In [36]:
type(record)
Out[36]:
dict
In [77]:
fd = open("record.txt",'w')

fd.write(js)

fd.close()
In [75]:
fd = open("record.txt",'r')

txt = fd.read()

fd.close()
In [76]:
txt
Out[76]:
'{"11602259": {"name": "Gurpreet Singh", "Pno": 5678, "cgpa": 8.2}, "11602261": {"name": "Rishu Kumar", "Pno": 8984, "cgpa": 7.8}}'
In [41]:
record = json.loads(txt)
In [42]:
record
Out[42]:
{'11602259': {'Pno': 1234, 'cgpa': 7.5, 'name': 'Ashish Jangra'},
 '11602260': {'Pno': 5678,
  'cgpa': 4.199999999999999,
  'name': 'Gurpreet Singh'},
 '11602261': {'Pno': 8984, 'cgpa': 7.8, 'name': 'Rishu Kumar'}}
In [44]:
record['11602259']
Out[44]:
{'Pno': 1234, 'cgpa': 7.5, 'name': 'Ashish Jangra'}
In [45]:
import time
In [46]:
time.ctime()
Out[46]:
'Tue Aug 31 13:40:02 2021'
In [49]:
record.values()
Out[49]:
dict_values([{'name': 'Ashish Jangra', 'Pno': 1234, 'cgpa': 7.5}, {'name': 'Gurpreet Singh', 'Pno': 5678, 'cgpa': 4.199999999999999}, {'name': 'Rishu Kumar', 'Pno': 8984, 'cgpa': 7.8}])
